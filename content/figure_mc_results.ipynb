# %% [markdown]
# # Interactive training diagnostics: mc_maze
#
# This notebook queries the e-prop dashboard API through `Dash_client.py`. If the API is unavailable, the client uses the bundled training log as a build fallback.

# %%
#| label: fig-mc-results-cell
from Dash_client import EpropClient

client = EpropClient()
client.training_figure("mc_maze")
